# %%
import pandas as pd
import numpy as np
data = pd.read_csv("Weather-2020-2025.csv")
data.head()
# Out:
#    location_id              time  temperature_2m  relative_humidity_2m (%)  \
# 0            0  2024-01-01T00:00             7.7                        77
# 1            0  2024-01-01T01:00             7.6                        77
# 2            0  2024-01-01T02:00             7.3                        78
# 3            0  2024-01-01T03:00             7.0                        80
# 4            0  2024-01-01T04:00             6.9                        80
#
#    wind_speed_10m (km/h)  precipitation (mm)  is_day  wind_speed_100m (km/h)  \
# 0                   30.6                 0.0       0                    48.2
# 1                   29.5                 0.0       0                    47.4
# 2                   29.0                 0.0       0                    47.0
# 3                   26.8                 0.0       0                    44.1
# 4                   26.0                 0.0       0                    42.7
#
#    wind_gusts_10m (km/h)  wind_direction_100m  wind_direction_10m  \
# 0                   51.8                  246                 243
# 1                   50.8                  249                 246
# 2                   49.3                  248                 245
# 3                   48.2                  251                 248
# 4                   44.6                  254                 251
#
#    cloud_cover (%)  vapour_pressure_deficit (kPa)
# 0               90                           0.25
# 1               60                           0.24
# 2               22                           0.22
# 3               33                           0.20
# 4               46                           0.20

# %%
data['time'] = pd.to_datetime(data['time'])
data.tail()
# Out:
#        location_id                time  temperature_2m  \
# 52627            2 2025-12-31 19:00:00            10.4
# 52628            2 2025-12-31 20:00:00            10.4
# 52629            2 2025-12-31 21:00:00            10.6
# 52630            2 2025-12-31 22:00:00            10.5
# 52631            2 2025-12-31 23:00:00            10.1
#
#        relative_humidity_2m (%)  wind_speed_10m (km/h)  precipitation (mm)  \
# 52627                        86                    6.1                 0.0
# 52628                        87                    5.7                 0.0
# 52629                        87                    5.5                 0.0
# 52630                        89                    9.0                 0.0
# 52631                        87                   10.1                 0.0
#
#        is_day  wind_speed_100m (km/h)  wind_gusts_10m (km/h)  \
# 52627       0                    13.0                   11.9
# 52628       0                    13.1                   11.9
# 52629       0                    13.3                   11.2
# 52630       0                    19.8                   16.2
# 52631       0                    21.9                   19.8
#
#        wind_direction_100m  wind_direction_10m  cloud_cover (%)  \
# 52627                   65                  45              100
# 52628                   77                  58              100
# 52629                   91                  67              100
# 52630                  106                  91              100
# 52631                  104                  87              100
#
#        vapour_pressure_deficit (kPa)
# 52627                           0.17
# 52628                           0.17
# 52629                           0.16
# 52630                           0.14
# 52631                           0.16

# %%
data["location_id"]=data["location_id"].replace({0: "london", 1:"Dublin" , 2:"Lisbon"})
display(data.tail())
# Out:
#       location_id                time  temperature_2m  \
# 52627      Lisbon 2025-12-31 19:00:00            10.4
# 52628      Lisbon 2025-12-31 20:00:00            10.4
# 52629      Lisbon 2025-12-31 21:00:00            10.6
# 52630      Lisbon 2025-12-31 22:00:00            10.5
# 52631      Lisbon 2025-12-31 23:00:00            10.1
#
#        relative_humidity_2m (%)  wind_speed_10m (km/h)  precipitation (mm)  \
# 52627                        86                    6.1                 0.0
# 52628                        87                    5.7                 0.0
# 52629                        87                    5.5                 0.0
# 52630                        89                    9.0                 0.0
# 52631                        87                   10.1                 0.0
#
#        is_day  wind_speed_100m (km/h)  wind_gusts_10m (km/h)  \
# 52627       0                    13.0                   11.9
# 52628       0                    13.1                   11.9
# 52629       0                    13.3                   11.2
# 52630       0                    19.8                   16.2
# 52631       0                    21.9                   19.8
#
#        wind_direction_100m  wind_direction_10m  cloud_cover (%)  \
# 52627                   65                  45              100
# 52628                   77                  58              100
# 52629                   91                  67              100
# 52630                  106                  91              100
# 52631                  104                  87              100
#
#        vapour_pressure_deficit (kPa)
# 52627                           0.17
# 52628                           0.17
# 52629                           0.16
# 52630                           0.14
# 52631                           0.16

# %%
data.groupby("location_id")["temperature_2m"].min()
lowest_temp_value=data.groupby("location_id")["temperature_2m"].min()
lowest_temp_location=lowest_temp_value.idxmin()
lowest_temp_value=lowest_temp_value.min()
print(f"location with the lowest temperature: {lowest_temp_location}(total: {lowest_temp_value})")
# Out:
# location with the lowest temperature: london(total: -5.1)

# %%
data.groupby('location_id')['temperature_2m'].mean()
#lowest average temperature
# Out:
# location_id
# Dublin    11.225325
# Lisbon    17.464449
# london    12.069300
# Name: temperature_2m, dtype: float64

# %%
data.groupby("location_id")["precipitation (mm)"].sum()
#lowest average precipitation
lowest_p_value=data.groupby("location_id")["precipitation (mm)"].sum()
lowest_p_location=lowest_p_value.idxmin()
lowest_p_value=lowest_p_value.min()
print(f"location with the lowest precipitation: {lowest_p_location}(total: {lowest_p_value})")
# Out:
# location with the lowest precipitation: london(total: 1507.0)

# %%
#highest wind speed at 100m
avg_wind=data.groupby("location_id")["wind_speed_100m (km/h)"].mean()
max_location = avg_wind.idxmax()
max_speed = avg_wind.max() 
print(f"Location with highest average wind speed: {max_location}(total: {max_speed}km/h)")
# Out:
# Location with highest average wind speed: Dublin(total: 25.924304605563155km/h)

# %%
#most consistent wind direction at 100m
def directional_consistency(x):
    rad = np.deg2rad(x.dropna())
    return np.sqrt(
        np.mean(np.cos(rad))**2 +
        np.mean(np.sin(rad))**2
    )

consistency = (
    data.groupby("location_id")["wind_direction_100m"]
        .apply(directional_consistency)
)

best_location = consistency.idxmax()
best_score = consistency.max()

print(f"Most consistent wind direction: {best_location}")
print(f"Consistency score: {best_score:.4f}")
# Out:
# Most consistent wind direction: Lisbon
# Consistency score: 0.3905

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.ioff()

# %%
#histogram for wind direction of each city overlapping
london = data[data["location_id"] == 0].copy()

dublin = data[data["location_id"] == 1].copy()

lisbon = data[data["location_id"] == 2].copy()
bins = 50
plt.hist(london["wind_direction_100m"], bins=bins, label="London", alpha = 0.75)
plt.hist(lisbon["wind_direction_100m"], bins=bins, label="Lisbon", alpha = 0.75)
plt.hist(dublin["wind_direction_100m"], bins=bins, label="Dublin", alpha = 0.75)

plt.xlabel("wind direction at 100m")
plt.ylabel("Frequency")
plt.title("wind direction at 100m Distribution in Cities")
plt.legend() 
plt.show()

# %%
#wind speed distribution for each city

london = data[data["location_id"] == 0].copy()
bins = 50
plt.hist(london["wind_speed_100m (km/h)"], bins=bins, label="London", alpha = 0.75)
plt.xlabel("wind speed at 100m")
plt.ylabel("Frequency")
plt.title("wind speed at 100m in London")
plt.legend()
plt.show()

# %%
# Bar chart for the average temperature each month in Dublin
dublin = data[data['location_id'] == 1].copy()

dublin["Month"] = dublin["time"].dt.month


mean_temp_month = dublin.groupby("Month")["temperature_2m"].mean()

print(mean_temp_month)

month_labels = ["Jan", "Feb", "Mar", "Apr", "May", "Jun",
                "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]

plt.figure(figsize=(10,5))
plt.bar(month_labels, mean_temp_month.values)

plt.xlabel("Month")
plt.ylabel("Average Temperature (°C)")
plt.title("Average Temperature in Dublin")

plt.show()
# Out:
# Series([], Name: temperature_2m, dtype: float64)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /opt/python-envs/training/lib/python3.14/site-packages/matplotlib/axes/_axes.py:2523, in Axes.bar(self, x, height, width, bottom, align, **kwargs)
#    2522 try:
# -> 2523     x, height, width, y, linewidth, hatch = np.broadcast_arrays(
#    2524         # Make args iterable too.
#    2525         np.atleast_1d(x), height, width, y, linewidth, hatch
#    2526     )
#    2527 except ValueError as e:
#
# File /opt/python-envs/training/lib/python3.14/site-packages/numpy/lib/_stride_tricks_impl.py:577, in broadcast_arrays(subok, *args)
#     575 args = [np.array(_m, copy=None, subok=subok) for _m in args]
# --> 577 shape = _broadcast_shape(*args)
#     579 result = [array if array.shape == shape
#     580           else _broadcast_to(array, shape, subok=subok, readonly=False)
#     581                           for array in args]
#
# File /opt/python-envs/training/lib/python3.14/site-packages/numpy/lib/_stride_tricks_impl.py:452, in _broadcast_shape(*args)
#     450 # use the old-iterator because np.nditer does not handle size 0 arrays
#     451 # consistently
# --> 452 b = np.broadcast(*args[:64])
#     453 # unfortunately, it cannot handle 64 or more arguments directly
#
# ValueError: shape mismatch: objects cannot be broadcast to a single shape.  Mismatch is between arg 0 with shape (12,) and arg 1 with shape (0,).
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 15
#      11 month_labels = ["Jan", "Feb", "Mar", "Apr", "May", "Jun",
#      12                 "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]
#      13
#      14 plt.figure(figsize=(10,5))
# ---> 15 plt.bar(month_labels, mean_temp_month.values)
#      16
#      17 plt.xlabel("Month")
#      18 plt.ylabel("Average Temperature (°C)")
#
# File /opt/python-envs/training/lib/python3.14/site-packages/matplotlib/pyplot.py:3138, in bar(x, height, width, bottom, align, data, **kwargs)
#    3127 @_copy_docstring_and_deprecators(Axes.bar)
#    3128 def bar(
#    3129     x: float | ArrayLike,
#    (...)   3136     **kwargs,
#    3137 ) -> BarContainer:
# -> 3138     return gca().bar(
#    3139         x,
#    3140         height,
#    3141         width=width,
#    3142         bottom=bottom,
#    3143         align=align,
#    3144         **({"data": data} if data is not None else {}),
#    3145         **kwargs,
#    3146     )
#
#     [... skipping hidden 1 frame]
#
# File /opt/python-envs/training/lib/python3.14/site-packages/matplotlib/axes/_axes.py:2540, in Axes.bar(self, x, height, width, bottom, align, **kwargs)
#    2538     error_message = error_message.replace(arg, name)
#    2539 if error_message != str(e):
# -> 2540     raise ValueError(error_message) from e
#    2541 else:
#    2542     raise
#
# ValueError: shape mismatch: objects cannot be broadcast to a single shape.  Mismatch is between 'x' with shape (12,) and 'height' with shape (0,).

# %%
    # histogram for wind speed at 100m distribution for dublin
    dublin = data[data["location_id"] == 1].copy()
    bins = 50
    plt.hist(dublin["wind_speed_100m (km/h)"], bins=bins, label="Dublin", alpha = 0.75)
    plt.xlabel("wind speed at 100m")
    plt.ylabel("Frequency")
    plt.title("wind speed at 100m in Dublin")
    plt.legend()
        plt.show()

# %%
#wind speed distribution at 100m for Lisbon
lisbon = data[data["location_id"] == 2].copy()
bins = 50
plt.hist(lisbon["wind_speed_100m (km/h)"], bins=bins, label="Lisbon", alpha = 0.75)
plt.xlabel("wind speed at 100m")
plt.ylabel("Frequency")
plt.title("wind speed at 100m in Lisbon")
plt.legend()
plt.show()

# %%
data.groupby('location_id')['precipitation (mm)'].mean()
# Out:
# location_id
# Dublin    0.122435
# Lisbon    0.089546
# london    0.085898
# Name: precipitation (mm), dtype: float64
